# %% [markdown]
# Name : Dhruva Makam
#
# Student ID : 801430413

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from io import StringIO
from matplotlib import markers

# %% [markdown]
# Function to load data from a URL

# %%
def load_data(url):
    response = requests.get(url)
    data = pd.read_csv(StringIO(response.text)) 
    return data

# %% [markdown]
# Loading the data from the Github URL

# %%
# Load the data from the GitHub URL
github_url = "https://github.com/dhruvamakam/Linear-regression/blob/main/D3.csv"
data = load_data(github_url)
display(data)
# Out:
#           X1        X2        X3         Y
# 0   0.000000  3.440000  0.440000  4.387545
# 1   0.040404  0.134949  0.888485  2.679650
# 2   0.080808  0.829899  1.336970  2.968490
# 3   0.121212  1.524848  1.785455  3.254065
# 4   0.161616  2.219798  2.233939  3.536375
# ..       ...       ...       ...       ...
# 95  3.838384  1.460202  3.046061 -4.440595
# 96  3.878788  2.155152  3.494545 -4.458663
# 97  3.919192  2.850101  3.943030 -4.479995
# 98  3.959596  3.545051  0.391515 -3.304593
# 99  4.000000  0.240000  0.840000 -5.332455
#
# [100 rows x 4 columns]

# %% [markdown]
# Map column names to match with the variable names used in code

# %%
data = data.rename(columns={'X1': 'x1', 'X2': 'x2', 'X3': 'x3', 'Y': 'y'})

# Separate explanatory variables
x1 = data['x1']
x2 = data['x2']
x3 = data['x3']
y = data['y']
m=len(x1)
print(m)
# Out:
# 100

# %% [markdown]
# Gradient Descent function and Loss Function

# %%
def gradient_descent(X, Y, initial_theta, learning_rate, num_of_iterations):
    m = len(Y)
    theta = initial_theta
    losses = []

    for i in range(num_of_iterations):
        predictions = X.dot(theta)
        error = predictions - Y
        gradient = (X.T.dot(error) / m)
        theta -= learning_rate * gradient
        loss = np.sum(error**2) / (2 * m)
        losses.append(loss)

    return theta, losses

# %% [markdown]
# Problem 1 - Linear Regression for Each Explanatory Variable Individually

# %%
learning_rate = 0.07
num_iterations = 7777
initial_theta = np.zeros(2)
print(initial_theta)
# Out:
# [0. 0.]

# %%
theta1, cost_history1 = gradient_descent(np.column_stack((np.ones(len(x1)), x1)), y, initial_theta, learning_rate, num_iterations)
print('Final theta for X1 and Y:', theta1)
print('Final cost for X1 and Y =', cost_history1)
min(cost_history1)
# Out:
# Final theta for X1 and Y: [ 5.92794892 -2.03833663]
# Final cost for X1 and Y = [np.float64(5.524438459196242), np.float64(5.260629487170323), np.float64(5.088663296898383), np.float64(4.949219834362283), np.float64(4.822924587306721), np.float64(4.703397183627607), np.float64(4.588485816291432), np.float64(4.4774163100032585), np.float64(4.369864829609821), np.float64(4.265656223405591), np.float64(4.164665846013963), np.float64(4.066787561737012), np.float64(3.9719232740450376), np.float64(3.87997945806115), np.float64(3.790865972567445), np.float64(3.704495615242247), np.float64(3.620783921418257), np.float64(3.5396490437837826), np.float64(3.461011660097727), np.float64(3.384794891651937), np.float64(3.310924226814957), np.float64(3.239327447765595), np.float64(3.1699345597537865), np.float64(3.1026777226274063), np.float64(3.0374911844956034), np.float64(2.9743112174434554), np.float64(2.9130760552285118), np.float64(2.8537258328961337), np.float64(2.7962025282539344), np.float64(2.7404499051478397), np.float64(2.686413458484272), np.float64(2.6340403609446588), np.float64(2.5832794113401922), np.float64(2.5340809845563217), np.float64(2.4863969830380572), np.float64(2.4401807897
# np.float64(3.599366018168041)

# %%
plt.scatter(x2, y, label='Actual Values', color='green')
plt.plot(x2, np.column_stack((np.ones(len(x2)), x2)).dot(theta2), label='Linear Regression', color='red')
plt.grid(linestyle='-')
plt.xlabel('x2')
plt.ylabel('y')
plt.title('Linear Regression Model for x2 and y')
plt.legend()
plt.show()

# %%
theta3, cost_history3 = gradient_descent(np.column_stack((np.ones(len(x3)), x3)), y, initial_theta, learning_rate, num_iterations)
print('Final theta for X3 and Y:', theta3)
print('cost_history for X3 and Y =', cost_history3)
print('min cost history3: ',min(cost_history3))
# Out:
# Final theta for X3 and Y: [ 2.8714221  -0.52048288]
# cost_history for X3 and Y = [np.float64(4.407877431359309), np.float64(4.295236611568891), np.float64(4.2444125635899095), np.float64(4.214997201340545), np.float64(4.193239692568139), np.float64(4.17445296490071), np.float64(4.157031964016124), np.float64(4.140419869606488), np.float64(4.124416604332498), np.float64(4.1089437183165325), np.float64(4.0939644401520106), np.float64(4.079456484344218), np.float64(4.065402796081307), np.float64(4.051788394945976), np.float64(4.038599292544779), np.float64(4.025822115551285), np.float64(4.0134439688672), np.float64(4.00145238069376), np.float64(3.9898352757147415), np.float64(3.97858095809161), np.float64(3.967678098041044), np.float64(3.9571157198690874), np.float64(3.946883190731698), np.float64(3.936970209866226), np.float64(3.9273667981999445), np.float64(3.918063288296965), np.float64(3.909050314623803), np.float64(3.900318804120543), np.float64(3.8918599670669978), np.float64(3.8836652882342877), np.float64(3.8757265183128116), np.float64(3.868035665607936), np.float64(3.860584987995012), np.float64(3.853366985125636), np.float64(3.8463743908773025), np.float64(3.8396001660388386), np.float64(3.833037491224267), np.float64(3.826679760007956), np.float64(3.8205205722741518), np.float64(3.814553727774195), np.float64(3.808773219884939), np.float64(3.8031732295620824), np.float64(3.797748119482332), np.float64(3.7924924283684915), np.float64(3.7874008654917897), np.float64(3.782468305345863), np.float64(3.777689782487097), np.float64(3.7730604865360635), np.float64(3.7685757573350873), np.float64(3.764231080257008), np.float64(3.7600220816604666), np.float64(3.7559445244870977), np.float64(3.75199430399623), np.float64(3.7481674436327785), np.float64(3.7444600910241816), np.float64(3.7408685141023432), np.float64(3.7373890973466843), np.float64(3.734018338144524), np.float64(3.7307528432651087), np.float64(3.7275893254437675), np.float64(3.724524600072729), np.float64(3.7215555819952817), np.float64(3.718679282400052), np.float64(3.715892805812264), np.float64(3.7131933471789718), np.float64(3.710578189045291), np.float64(3.7080446988188402), np.float64(3.705590326119592), np.float64(3.703212600212493), np.float64(3.7009091275202577), np.float64(3.698677589213828), np.float64(3.6965157388780967), np.float64(3.6944214002505067), np.float64(3.692392465030283), np.float64(3.6904268907560795), np.float64(3.688522698749896), np.float64(3.6866779721252168), np.float64(3.6848908538573335), np.float64(3.683159544913955), np.float64(3.681482302444169), np.float64(3.6798574380239772), np.float64(3.6782833159566173), np.float64(3.6767583516259577), np.float64(3.6752810099013193), np.float64(3.6738498035921134), np.float64(3.672463291950728), np.float64(3.671120079222187), np.float64(3.66981881323908), np.float64(3.668558184060387), np.float64(3.6673369226528005), np.float64(3.6661537996132374), np.float64(3.6650076239312317), np.float64(3.663897241789992), np.float64(3.6628215354048894), np.float64(3.6617794218982187), np.float64(3.660769852209104), np.float64(3.659791810037447), np.float64(3.658844310820847), np.float64(3.657926400743473), np.float64(3.6570371557759), np.float64(3.656175680744906), np.float64(3.655341108432339), np.float64(3.6545325987021147), np.float64(3.6537493376544807), np.float64(3.6529905368066924), np.float64(3.652255432299268), np.float64(3.651543284127044), np.float64(3.65085337539423), np.float64(3.6501850115927392), np.float64(3.649537519903045), np.float64(3.6489102485168847), np.float64(3.6483025659810924), np.float64(3.647713860561949), np.float64(3.647143539629364), np.float64(3.646591029060296), np.float64(3.6460557726608), np.float64(3.64553723160613), np.float64(3.645034883898319), np.float64(3.6445482238406988), np.float64(3.644076761528839), np.float64(3.6436200223573705), np.float64(3.643177546542218), np.float64(3.6427488886577515), np.float64(3.64233361718839), np.float64(3.64193131409421), np.float64(3.641541574390116), np.float64(3.64116400573816 ...
# min cost history3:  3.6294511246079137

# %%
plt.scatter(x3, y, label='Actual Values', color='orange')
plt.plot(x3, np.column_stack((np.ones(len(x3)), x3)).dot(theta3), label='Linear Regression', color='blue')
plt.grid(linestyle='-')
plt.xlabel('x3')
plt.ylabel('y')
plt.title('Linear Regression Model for x3 and y')
plt.legend()
plt.show()

# %% [markdown]
# Taking different learning rates for X1, X2 and X3 and plotting Loss Function
#
# First Learning rate was 0.07

# %%
theta1, cost_history1 = gradient_descent(np.column_stack((np.ones(len(x1)), x1)), y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history1)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations for x1 and y')
plt.show()

# %%
theta2, cost_history2 = gradient_descent(np.column_stack((np.ones(len(x2)), x2)), y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history2)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations for x2 and y')
plt.show()

# %%
theta3, cost_history1 = gradient_descent(np.column_stack((np.ones(len(x3)), x3)), y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history1)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations for x3 and y')
plt.show()

# %% [markdown]
# Next taking learning rate as 0.06

# %%
learning_rate = 0.06
num_iterations = 6666
initial_theta = np.zeros(2)
print(initial_theta)
# Out:
# [0. 0.]

# %%
theta1, cost_history2 = gradient_descent(np.column_stack((np.ones(len(x1)), x1)), y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history2)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations for x1 and y')
plt.show()

# %%
theta2, cost_history3 = gradient_descent(np.column_stack((np.ones(len(x2)), x2)), y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history3)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations for x2 and y')
plt.show()

# %%
theta3, cost_history3 = gradient_descent(np.column_stack((np.ones(len(x3)), x3)), y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history3)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations for x3 and y')
plt.show()

# %% [markdown]
# Next taking learning rate as 0.05

# %%
learning_rate = 0.05
num_iterations = 5555
initial_theta = np.zeros(2)
print(initial_theta)
# Out:
# [0. 0.]

# %%
theta1, cost_history1 = gradient_descent(np.column_stack((np.ones(len(x1)), x1)), y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history1)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations for x1 and y')
plt.show()

# %%
theta2, cost_history2 = gradient_descent(np.column_stack((np.ones(len(x2)), x2)), y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history2)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations for x2 and y')
plt.show()

# %%
theta3, cost_history3 = gradient_descent(np.column_stack((np.ones(len(x3)), x3)), y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history3)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations for x3 and y')
plt.show()

# %% [markdown]
# Next taking learning rate very high 0.3

# %%
learning_rate = 0.3
num_iterations = 2000
initial_theta = np.zeros(2)
print(initial_theta)
# Out:
# [0. 0.]

# %%
theta1, cost_history1 = gradient_descent(np.column_stack((np.ones(len(x1)), x1)), y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history1)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations for x1 and y')
plt.show()

# %%
theta2, cost_history2 = gradient_descent(np.column_stack((np.ones(len(x2)), x2)), y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history2)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations for x2 and y')
plt.show()

# %%
theta3, cost_history3 = gradient_descent(np.column_stack((np.ones(len(x3)), x3)), y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history3)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations for x3 and y')
plt.show()

# %% [markdown]
# Problem 2 - Linear Regression with All Explanatory Variables

# %%
learning_rate = 0.03
num_iterations = 4000
initial_theta = np.zeros(4)

X = np.column_stack((np.ones(len(x1)), x1, x2, x3))
theta4, cost_history4 = gradient_descent(X, y, initial_theta, learning_rate, num_iterations)
print('Final theta for X1, X2, X3, and Y:', theta4)
plt.plot(cost_history4)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations for X1, X2, X3, and Y')
plt.show()

# Predict values for new inputs
test_data = np.array([[1, 1, 1, 1], [1, 2, 0, 4], [1, 3, 2, 1]])
predictions = test_data.dot(theta4)
print("values predicted for the new inputs:", predictions)
# Out:
# Final theta for X1, X2, X3, and Y: [ 5.31413463 -2.00371467  0.53256871 -0.2655971 ]
# values predicted for the new inputs: [3.57739158 0.2443169  0.10253095]

# %%
learning_rate = 0.01
num_iterations = 1000
initial_theta = np.zeros(4)

# %%
theta4, cost_history4 = gradient_descent(X, y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history4)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations for X1, X2, X3, and Y')
plt.show()

# %%
learning_rate = 0.2
num_iterations = 5000
initial_theta = np.zeros(4)

# %%
theta4, cost_history4 = gradient_descent(X, y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history4)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations')
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)

# %%
learning_rate = 0.8
num_iterations = 300
initial_theta = np.zeros(4)

# %%
theta4, cost_history4 = gradient_descent(X, y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history4)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations')
plt.show()
